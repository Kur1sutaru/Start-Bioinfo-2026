# %% [markdown]
# <a href="https://colab.research.google.com/github/Kur1sutaru/Start-Bioinfo-2026/blob/main/kokoro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import PathPatch
from matplotlib.path import Path

verts = [
    (0, -130), (-140, -30), (-140, 60), (0, 130), (140, 60), (140, -30), (0, -130)
]

# Equação paramétrica clássica do coração
t = np.linspace(0, 2 * np.pi, 1000)
x = 16 * np.sin(t) ** 3
y = 13 * np.cos(t) - 5*np.cos(2*t) - 2*np.cos(3*t) - np.cos(4*t)

fig, ax = plt.subplots(figsize=(5, 5), facecolor='white')
ax.fill(x, y, color='#e8181b')
ax.set_aspect('equal')
ax.axis('off')
plt.tight_layout()
plt.savefig('coracao.png', dpi=150, bbox_inches='tight')
plt.show()
